# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigomluz/codekdata/blob/main/webscraping_market_price_from_yahoo_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##webscraping market-price from yahoo-finance

# %% [markdown]
# ![analysis-4937349_1280.jpg](data:image/jpeg;base64,...)

# %%
#importando as bibliotecas
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
def marketPrice():
##BTC  
  # fazendo a request do site.
  r = requests.get('https://br.financas.yahoo.com/quote/BTC-USD?p=BTC-USD')

  soup = bs(r.content, 'html.parser')

  #print(soup.prettify())


  btc = soup.find('div', attrs={'class':'D(ib) Mend(20px)'})

  #print(btc)

  #localizando preço do bitcoin
  price = [btc.find('span', attrs={'class':"Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)"}).get_text()]

  #print(price)

  #localizando a valorização
  valorizacao = [btc.find('span', attrs={'class':"Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($positiveColor)"}).get_text()]
  #print(valorizacao)
  nome = ['BTC-USD']
  #criando um dicionáio
  #btc_usd = {'Nome':nome,'Price':price, 'Valorização':valorizacao}
  
  #criando um data frame a parir do dicionário
  #df = pd.DataFrame(btc_usd)

  #return df

##IBOVESPA

  # fazendo a request do site.
  r1 = requests.get('https://br.financas.yahoo.com/quote/%5EBVSP?p=^BVSP')

  soup = bs(r1.content, 'html.parser')

  #print(soup.prettify())


  ibv = soup.find('div', attrs={'class':'D(ib) Mend(20px)'})

  #print(btc)

  #localizando preço do bitcoin
  price.append(ibv.find('span', attrs={'class':"Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)"}).get_text())

  #print(price)
  nome.append('IBOVESPA')
  #localizando a valorização
  valorizacao.append(ibv.find('span', attrs={'class':"Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($negativeColor)"}).get_text())
  
  #print(valorizacao)

  #criando um dicionáio
  #ib = {'Nome':'IBOVESPA','Price':price, 'Valorização':valorizacao}
  
  #criando um data frame a parir do dicionário
  #df2 = pd.DataFrame(ib)

  #return df2


##OURO

  # fazendo a request do site.
  r2 = requests.get('https://br.financas.yahoo.com/quote/GC=F?p=GC=F')

  soup = bs(r2.content, 'html.parser')

  #print(soup.prettify())


  GOLD = soup.find('div', attrs={'class':'D(ib) Mend(20px)'})

  #print(btc)
  nome.append('OURO')
  #localizando preço do bitcoin
  price.append(GOLD.find('span', attrs={'class':"Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)"}).get_text())

  #print(price)

  #localizando a valorização
  valorizacao.append(GOLD.find('span', attrs={'class':"Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($positiveColor)"}).get_text())
  #print(valorizacao)

## S&P500
   # fazendo a request do site.
  r3 = requests.get('https://br.financas.yahoo.com/quote/%5EGSPC?p=^GSPC')

  soup = bs(r3.content, 'html.parser')

  #print(soup.prettify())


  SP = soup.find('div', attrs={'class':'D(ib) Mend(20px)'})

  #print(btc)

  #localizando preço do bitcoin
  price.append(SP.find('span', attrs={'class':"Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)"}).get_text())

  #print(price)
  nome.append('S&P 500')

  #localizando a valorização
  valorizacao.append(SP.find('span', attrs={'class':"Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($negativeColor)"}).get_text())
  #print(valorizacao)





  #criando um dicionáio
  market = {'Nome':nome,'Price':price, 'Valorização':valorizacao}
  
  #criando um data frame a parir do dicionário
  df = pd.DataFrame(market)

  return df

print(marketPrice())
# Out:
#        Nome       Price       Valorização
# 0   BTC-USD   18.604,32  +360,06 (+1,97%)
# 1  IBOVESPA  106.042,48   -76,62 (-0,07%)
# 2      OURO    1.869,60    +8,10 (+0,44%)
# 3   S&P 500    3.557,54   -24,33 (-0,68%)
